# %%
#라이프니츠 파이공식 

s = 0
for n in range(1,100):
    s = s+((-1)**n)/(2*n+1)
    print(s)
# Out:
# 0.6666666666666667
# 0.8666666666666667
# 0.7238095238095239
# 0.8349206349206351
# 0.7440115440115441
# 0.8209346209346211
# 0.7542679542679545
# 0.8130914836797192
# 0.7604599047323508
# 0.8080789523513985
# 0.7646006914818333
# 0.8046006914818333
# 0.7675636544447964
# 0.802046413065486
# 0.769788348549357
# 0.8000913788523872
# 0.7715199502809587
# 0.7985469773079856
# 0.77290595166696
# 0.797296195569399
# 0.7740403816159106
# 0.7962626038381329
# 0.774986008093452
# 0.7953941713587581
# 0.7757863282215032
# 0.7946542527498051
# 0.7764724345679869
# 0.7940162942171096
# 0.7770671416747368
# 0.7934605842976876
# 0.7775875684246718
# 0.7929721838092871
# 0.7780468106749587
# 0.7925395642981471
# 0.7784550572558936
# 0.7921536873928798
# 0.7788203540595465
# 0.7918073670465595
# 0.7791491391984583
# 0.7914948182108039
# 0.7794466254397195
# 0.7912113313220724
# 0.7797170784485092
# 0.790953033504689
# 0.7799640225156781
# 0.7907167106877211
# 0.7801903948982474
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
pi= math.pi
s = 1
for n i+n range(1,100):
    s = s+((-1)**n)/(2*n+1)
    plt.plot(n,s)

    
a = [1/4*pi]
plt.plot([0,20,40,60,80,100],[a,a,a,a,a,a])
# Out:
#   File "<ipython-input-2-f54be2acb263>", line 6
#     for n i+n range(1,100):
#           ^
# SyntaxError: invalid syntax

# %%
#로지스틱맵
r = float(input('r:'))
a = float(input('a:'))
for n in range(10):
    n = n+1
    print(n)
    a = r*a*(1-a)
    print(a)

# %%
#싱크 함수 



def f(x,n):
    i, s = 1, 0
    while (i<=n):
        s = s + 4/np.pi/i*np.sin(i*x)
        
    return s
